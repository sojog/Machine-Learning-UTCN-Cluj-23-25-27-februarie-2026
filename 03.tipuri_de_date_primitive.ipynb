# %%
x = True
x, type(x)
# Out:
# (True, bool)

# %%
x = 10
x, type(x)
# Out:
# (10, int)

# %%
x = 123.31
x, type(x)
# Out:
# (123.31, float)

# %%
x = "tipuri"
x, type(x)
# Out:
# ('tipuri', str)

# %%
# !python3 --version
# Out:
# Python 3.14.0
