# %% [markdown]
# # pip install scikit-learn

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
regr = make_regression()
type(regr), len(regr)
# Out:
# (tuple, 2)

# %%
x, y = regr

# %%
type(x), x.shape
# Out:
# (numpy.ndarray, (100, 100))

# %%
regr = make_regression(n_samples=50, n_features=1)
x, y = regr

# %%
plt.scatter(x, y, c="red");
plt.plot(x, y);

# %%
x, y = make_regression(n_samples=50, n_features=1, noise=5)
plt.scatter(x, y, c="red");
# plt.plot(x, y);

# %%
x, y = make_regression(n_samples=50, n_features=1, noise=5)
plt.scatter(x, y, c="red");

# %%
x, y = make_regression(n_samples=50, n_features=1, noise=20)
plt.scatter(x, y, c="red");

# %%
x, y = make_regression(n_samples=50, n_features=1, noise=50)
plt.scatter(x, y, c="red");

# %%
x, y = make_regression(n_samples=500, n_features=1, noise=50)
plt.scatter(x, y, c="red");

# %%
x, y = make_regression(n_samples=5000, n_features=1, noise=50)
plt.scatter(x, y, c="red");

# %%
x
# Out:
# array([[ 0.17965132],
#        [ 0.23642874],
#        [ 1.01155779],
#        ...,
#        [ 0.08339693],
#        [-1.37060197],
#        [ 1.26246357]], shape=(5000, 1))
