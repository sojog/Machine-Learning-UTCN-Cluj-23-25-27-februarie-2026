# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(10, 20)
plt.show()

# %%
plt.scatter([4, 10], [6, 20]);

# %%
plt.scatter([4, 10, 40], [6, 20, 30]);

# %%
plt.plot([4, 10, 40], [6, 20, 30]);

# %%
plt.plot([4, 10, 40], [6, 20, 30]);
plt.scatter([4, 10, 40], [6, 20, 30]);

# %%
plt.plot([4, 10, 40], [6, 20, 30]);
plt.scatter([4, 10, 40], [6, 20, 30], c="red");

# %%
import numpy as np

# %%
x = np.arange(2, 8)
x
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
y = x * 2 + 1
y
# Out:
# array([ 5,  7,  9, 11, 13, 15])

# %%
plt.plot(x, y);
plt.scatter(x, y, c="red");

# %%
plt.plot(x, y)
plt.scatter(x, y, c="red")
plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y");
