# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
65_000, 65000
# Out:
# (65000, 65000)

# %%
# mp, pret
apartamente = np.array([
   (35, 50_000), (45, 65_000),(50, 80_000), (55, 175_000), (55, 185_000), (60, 75_000), (65, 115_000), (75, 185_000),(80, 112_000
 ), (80, 200_000), (85, 215_000)
])

# %%
suprafata = apartamente[0][0]
suprafata
# Out:
# np.int64(35)

# %%
suprafete = apartamente[:, 0]
suprafete
# Out:
# array([35, 45, 50, 55, 55, 60, 65, 75, 80, 80, 85])

# %%
preturi = apartamente[:, 1]
preturi
# Out:
# array([ 50000,  65000,  80000, 175000, 185000,  75000, 115000, 185000,
#        112000, 200000, 215000])

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, preturi);

# %%
plt.scatter(suprafete, preturi / 1000);
plt.plot(suprafete, preturi/ 1000);

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, preturi);
plt.plot(suprafete, 2000 * suprafete + 0);

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, preturi);
plt.plot(suprafete, 2000 * suprafete + 0, c="orange");
plt.plot(suprafete, 2500 * suprafete + 0, c="green");

# %% [markdown]
# # pip install scipy

# %%
from scipy import stats

# %%
result = stats.linregress(suprafete, preturi)
result.slope, result.intercept
# Out:
# (np.float64(2608.159722222222), np.float64(-29962.673611111124))

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, preturi);
plt.plot(suprafete, 2000 * suprafete + 0, c="orange");
plt.plot(suprafete, 2500 * suprafete + 0, c="green");

plt.plot(suprafete, result.slope * suprafete + result.intercept, c="black");

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, result.slope * suprafete + result.intercept, c="black");

# %%
def f(x):
    return result.slope * x + result.intercept

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, result.slope * suprafete + result.intercept, c="black");
x = 70
plt.scatter(x, f(x), c="red")

# %%
f(x)
# Out:
# np.float64(152608.50694444444)

# %%
plt.scatter(suprafete, preturi);
plt.plot(suprafete, result.slope * suprafete + result.intercept, c="black");
x = 70
plt.scatter(x, f(x), c="red")
