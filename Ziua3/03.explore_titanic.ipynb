# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Titanic-Dataset.csv", index_col=0)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.Survived.unique()
# Out:
# array([0, 1])

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
df['Name'].nunique()
# Out:
# 891

# %% [markdown]
# # Facem drop la nume -> toate sunt unice

# %%
df = df.drop("Name", axis=1)
df
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# PassengerId
# 1                   0       3    male  22.0      1      0         A/5 21171
# 2                   1       1  female  38.0      1      0          PC 17599
# 3                   1       3  female  26.0      0      0  STON/O2. 3101282
# 4                   1       1  female  35.0      1      0            113803
# 5                   0       3    male  35.0      0      0            373450
# ...               ...     ...     ...   ...    ...    ...               ...
# 887                 0       2    male  27.0      0      0            211536
# 888                 1       1  female  19.0      0      0            112053
# 889                 0       3  female   NaN      1      2        W./C. 6607
# 890                 1       1    male  26.0      0      0            111369
# 891                 0       3    male  32.0      0      0            370376
#
#                 Fare Cabin Embarked
# ...

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Gen"] = df["Sex"].map({"female":1, "male":0})
df.head(2)
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Ticket     Fare  \
# PassengerId
# 1                   0       3    male  22.0      1      0  A/5 21171   7.2500
# 2                   1       1  female  38.0      1      0   PC 17599  71.2833
#
#             Cabin Embarked  Gen
# PassengerId
# 1             NaN        S    0
# 2             C85        C    1

# %%
df = df.drop("Sex", axis=1)
df.head(2)
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Ticket     Fare Cabin  \
# PassengerId
# 1                   0       3  22.0      1      0  A/5 21171   7.2500   NaN
# 2                   1       1  38.0      1      0   PC 17599  71.2833   C85
#
#             Embarked  Gen
# PassengerId
# 1                  S    0
# 2                  C    1

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# Gen           int64
# dtype: object

# %%
df["Ticket"].nunique()
# Out:
# 681

# %%
df = df.drop("Ticket", axis=1)
df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  Gen
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   NaN        S    0
# 2                   1       1  38.0      1      0  71.2833   C85        C    1
# 3                   1       3  26.0      0      0   7.9250   NaN        S    1
# 4                   1       1  35.0      1      0  53.1000  C123        S    1
# 5                   0       3  35.0      0      0   8.0500   NaN        S    0
# ...               ...     ...   ...    ...    ...      ...   ...      ...  ...
# 887                 0       2  27.0      0      0  13.0000   NaN        S    0
# 888                 1       1  19.0      0      0  30.0000   B42        S    1
# 889                 0       3   NaN      1      2  23.4500   NaN        S    1
# 890                 1       1  26.0      0      0  30.0000  C148        C    0
# 891                 0       3  32.0      0      0   7.7500   NaN        Q    0
#
# ...

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin        object
# Embarked     object
# Gen           int64
# dtype: object

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"] = df["Embarked"].map({'S':0, 'C':1, 'Q':2})
df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare Cabin  Embarked  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   NaN       0.0
# 2                   1       1  38.0      1      0  71.2833   C85       1.0
# 3                   1       3  26.0      0      0   7.9250   NaN       0.0
# 4                   1       1  35.0      1      0  53.1000  C123       0.0
# 5                   0       3  35.0      0      0   8.0500   NaN       0.0
# ...               ...     ...   ...    ...    ...      ...   ...       ...
# 887                 0       2  27.0      0      0  13.0000   NaN       0.0
# 888                 1       1  19.0      0      0  30.0000   B42       0.0
# 889                 0       3   NaN      1      2  23.4500   NaN       0.0
# 890                 1       1  26.0      0      0  30.0000  C148       1.0
# 891                 0       3  32.0      0      0   7.7500   NaN       2.0
#
#              Gen
# PassengerId
# 1              0
# ...

# %%
df["Embarked"].unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin        object
# Embarked    float64
# Gen           int64
# dtype: object

# %%
df["Cabin"].unique(), df["Cabin"].nunique()
# Out:
# (array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#         'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#         'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#         'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#         'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#         'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#         'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#         'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#         'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#         'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#         'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#         'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#         'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df["Cabin"] = df["Cabin"].str[0]
df.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare Cabin  Embarked  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500   NaN       0.0
# 2                   1       1  38.0      1      0  71.2833     C       1.0
# 3                   1       3  26.0      0      0   7.9250   NaN       0.0
# 4                   1       1  35.0      1      0  53.1000     C       0.0
# 5                   0       3  35.0      0      0   8.0500   NaN       0.0
#
#              Gen
# PassengerId
# 1              0
# 2              1
# 3              1
# 4              1
# 5              0

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin        object
# Embarked    float64
# Gen           int64
# dtype: object

# %%
df["Cabin"] = df["Cabin"].map({ value : index  for index, value in enumerate('ABCDEFGT') })
df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Cabin  Embarked  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500    NaN       0.0
# 2                   1       1  38.0      1      0  71.2833    2.0       1.0
# 3                   1       3  26.0      0      0   7.9250    NaN       0.0
# 4                   1       1  35.0      1      0  53.1000    2.0       0.0
# 5                   0       3  35.0      0      0   8.0500    NaN       0.0
# ...               ...     ...   ...    ...    ...      ...    ...       ...
# 887                 0       2  27.0      0      0  13.0000    NaN       0.0
# 888                 1       1  19.0      0      0  30.0000    1.0       0.0
# 889                 0       3   NaN      1      2  23.4500    NaN       0.0
# 890                 1       1  26.0      0      0  30.0000    2.0       1.0
# 891                 0       3  32.0      0      0   7.7500    NaN       2.0
#
#              Gen
# PassengerId
# ...

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin       float64
# Embarked    float64
# Gen           int64
# dtype: object

# %%
plt.scatter(df["Age"], df["Gen"]);

# %%
plt.scatter(df["Age"], df["Gen"], c=df["Survived"]);

# %%
plt.rcParams["figure.figsize"] #  [6.4, 4.8]
# Out:
# [6.4, 4.8]

# %%
plt.rcParams["figure.figsize"] =  [6.4 * 2, 4.8]

# %%
plt.scatter(df["Age"], df["Gen"], c=df["Survived"]);

# %%
survived_df = df[df["Survived"] == 1]
unsurvived_df = df[df["Survived"] == 0]

plt.scatter(survived_df["Age"], survived_df["Gen"], c="green");
plt.scatter(unsurvived_df["Age"], unsurvived_df["Gen"], c="red");
plt.legend(["Survived", "Dead"])

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare  \
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# Cabin     0.018825  0.598211 -0.177444  0.035571  0.023298 -0.298487
# Embarked  0.108669  0.043835  0.012186 -0.060606 -0.079320  0.063462
# Gen       0.543351 -0.131900 -0.093254  0.114631  0.245489  0.182333
#
#              Cabin  Embarked       Gen
# Survived  0.018825  0.108669  0.543351
# Pclass    0.598211  0.043835 -0.131900
# Age      -0.177444  0.012186 -0.093254
# SibSp     0.035571 -0.060606  0.114631
# Parch     0.023298 -0.079320  0.245489
# ...

# %%
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] =  [6.4, 4.8]
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"] =  [6.4, 4.8]
sns.heatmap(df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
adults_df =  df [df["Age"] > 14]

plt.rcParams["figure.figsize"] =  [6.4, 4.8]
sns.heatmap(adults_df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# # Ensemble (random forest)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_model = RandomForestClassifier()
rfc_model
# Out:
# RandomForestClassifier()

# %%
df.head(2)
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Cabin  Embarked  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500    NaN       0.0
# 2                   1       1  38.0      1      0  71.2833    2.0       1.0
#
#              Gen
# PassengerId
# 1              0
# 2              1

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# Gen           0
# dtype: int64

# %%
df = df.drop("Cabin", axis=1)
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# Gen           0
# dtype: int64

# %%
df[df["Embarked"].isna()]
# Out:
#              Survived  Pclass   Age  SibSp  Parch  Fare  Embarked  Gen
# PassengerId
# 62                  1       1  38.0      0      0  80.0       NaN    1
# 830                 1       1  62.0      0      0  80.0       NaN    1

# %%
df["Embarked"].max()
# Out:
# np.float64(2.0)

# %%
df.loc[62, "Embarked"] = df["Embarked"].max()
df.loc[830, "Embarked"] = df["Embarked"].max()

# %%
df[df["Embarked"].isna()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, Embarked, Gen]
# Index: []

# %%
df.keys()
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked',
#        'Gen'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# Gen           0
# dtype: int64

# %%
df[df["Age"].isna()]
# Out:
#              Survived  Pclass  Age  SibSp  Parch     Fare  Embarked  Gen
# PassengerId
# 6                   0       3  NaN      0      0   8.4583       2.0    0
# 18                  1       2  NaN      0      0  13.0000       0.0    0
# 20                  1       3  NaN      0      0   7.2250       1.0    1
# 27                  0       3  NaN      0      0   7.2250       1.0    0
# 29                  1       3  NaN      0      0   7.8792       2.0    1
# ...               ...     ...  ...    ...    ...      ...       ...  ...
# 860                 0       3  NaN      0      0   7.2292       1.0    0
# 864                 0       3  NaN      8      2  69.5500       0.0    1
# 869                 0       3  NaN      0      0   9.5000       0.0    0
# 879                 0       3  NaN      0      0   7.8958       0.0    0
# 889                 0       3  NaN      1      2  23.4500       0.0    1
#
# [177 rows x 8 columns]

# %%
x = df[df.keys()[1:]]
x.head()
# Out:
#              Pclass   Age  SibSp  Parch     Fare  Embarked  Gen
# PassengerId
# 1                 3  22.0      1      0   7.2500       0.0    0
# 2                 1  38.0      1      0  71.2833       1.0    1
# 3                 3  26.0      0      0   7.9250       0.0    1
# 4                 1  35.0      1      0  53.1000       0.0    1
# 5                 3  35.0      0      0   8.0500       0.0    0

# %%
y = df["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
rfc_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_model.score(x_test, y_test)
# Out:
# 0.8116591928251121

# %%
import joblib

# %%
joblib.dump(rfc_model, "titanic.job")
# Out:
# ['titanic.job']

# %%
joblib.load("titanic.job")
# Out:
# RandomForestClassifier()
